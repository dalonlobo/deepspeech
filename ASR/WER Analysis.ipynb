# %% [markdown]
# - 2 Videos have complete transcription using Deep Speech (DS) model and Liv ai (LA) model
# - Ouput is a dataframe consisting of 3 columns, Reference text, DS hypothesis, LA hypothesis
# - Pickle file names are: Vsg_PFQmw4I.b and Kgowgm1KeZ4.b

# %%
from __future__ import print_function, division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import text # WER calulation module from DS repo, it uses Lavenstien distance
import wer

# %matplotlib inline

# %%
with open("Vsg_PFQmw4I.b", "rb") as f1, \
        open("Kgowgm1KeZ4.b", "rb") as f2:
    vdf1 = pickle.load(f1)
    vdf2 = pickle.load(f2)

# %%
# Find the shape
print("vdf1: Number of audio segments:{}".format(vdf1.shape[0]))
print("vdf2: Number of audio segments:{}".format(vdf2.shape[0]))
# Out:
# vdf1: Number of audio segments:1574
# vdf2: Number of audio segments:1457

# %%
# For video 1
wer_v1 = []
for val in vdf1.iterrows():
    ref = val[1]["Reference"]
    ds_hyp = val[1]["Deepspeech hypothesis"]
    la_hyp = val[1]["Livai hypothesis"]
    if not ref:
        # Because text.wer throws ZeroDivisionError if ref is null
        wer_v1.append([1.0, 1.0])
        continue
    wer_v1.append([text.wer(ref, ds_hyp), text.wer(ref, la_hyp)])

# %%
# For video 2
wer_v2 = []
for val in vdf2.iterrows():
    ref = val[1]["Reference"]
    ds_hyp = val[1]["Deepspeech hypothesis"]
    la_hyp = val[1]["Livai hypothesis"]
    if not ref:
        # Because text.wer throws ZeroDivisionError if ref is null
        wer_v2.append([1.0, 1.0])
        continue
    wer_v2.append([text.wer(ref, ds_hyp), text.wer(ref, la_hyp)])

# %%
# Push the wer to data frame for easier calculations
werds_df1 = pd.DataFrame(wer_v1, columns=["WER for DS", "WER for LA"])
werds_df2 = pd.DataFrame(wer_v2, columns=["WER for DS", "WER for LA"])

# %%
# Plotting the graph for v1
sns.distplot(werds_df1["WER for DS"], label="WER for DS")
sns.distplot(werds_df1["WER for LA"], label="WER for LA")
plt.legend()
plt.show()

# %%
# Plotting the graph for v1
sns.distplot(wer_df2["WER for DS"], label="WER for DS")
sns.distplot(wer_df2["WER for LA"], label="WER for LA")
plt.legend()
plt.show()

# %% [markdown]
# ### Lower WER is better

# %%
# Look at these stats
werds_df1.describe()
# Out:
#         WER for DS   WER for LA
# count  1574.000000  1574.000000
# mean      0.472616     0.419199
# std       0.380904     0.395483
# min       0.000000     0.000000
# 25%       0.166667     0.125000
# 50%       0.400000     0.333333
# 75%       0.750000     0.625000
# max       4.000000     3.000000

# %%
# Look at these stats
werds_df2.describe()
# Out:
#         WER for DS   WER for LA
# count  1457.000000  1457.000000
# mean      0.533501     0.367991
# std       0.414186     0.388370
# min       0.000000     0.000000
# 25%       0.250000     0.100000
# 50%       0.500000     0.266667
# 75%       0.800000     0.500000
# max       5.000000     4.000000

# %% [markdown]
# ### Average of WER

# %%
print("WER average for video 1: ", werds_df1.mean(), sep="\n")
print("WER average for video 2: ", werds_df2.mean(), sep="\n")
# Out:
# WER average for video 1:
# WER for DS    0.472616
# WER for LA    0.419199
# dtype: float64
# WER average for video 2:
# WER for DS    0.533501
# WER for LA    0.367991
# dtype: float64

# %%
0.472616 - 0.419199
# Out:
# 0.05341699999999999

# %%
0.533501 - 0.367991
# Out:
# 0.16551

# %% [markdown]
# **For video 1, WER for LA is better by 5.34% <br />
#   For video 2, WER for LA is better by 16.55%**

# %% [markdown]
# ## Calculating WER using wer module

# %%
# For video 1
wer_v1 = []
for val in vdf1.iterrows():
    ref = val[1]["Reference"]
    ds_hyp = val[1]["Deepspeech hypothesis"]
    la_hyp = val[1]["Livai hypothesis"]
    if not ref:
        # Because text.wer throws ZeroDivisionError if ref is null
        wer_v1.append([1.0, 1.0])
        continue
    wer_v1.append([wer.wer(ref, ds_hyp), wer.wer(ref, la_hyp)])
# Out:
# wer.py:25: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if r[i-1] == h[j-1]:

# %%
# For video 2
wer_v2 = []
for val in vdf2.iterrows():
    ref = val[1]["Reference"]
    ds_hyp = val[1]["Deepspeech hypothesis"]
    la_hyp = val[1]["Livai hypothesis"]
    if not ref:
        # Because text.wer throws ZeroDivisionError if ref is null
        wer_v2.append([1.0, 1.0])
        continue
    wer_v2.append([wer.wer(ref, ds_hyp), wer.wer(ref, la_hyp)])

# %%
# Push the wer to data frame for easier calculations
wer_df1 = pd.DataFrame(wer_v1, columns=["WER for DS", "WER for LA"])
wer_df2 = pd.DataFrame(wer_v2, columns=["WER for DS", "WER for LA"])

# %% [markdown]
# ### Lower WER is better
#
# **Note the WER is in percentage here**

# %%
wer_df1.describe()
# Out:
#         WER for DS   WER for LA
# count  1574.000000  1574.000000
# mean     31.026844    29.045137
# std      29.317673    33.285246
# min       0.000000     0.000000
# 25%       9.090909     5.595238
# 50%      23.076923    19.148936
# 75%      43.463959    40.000000
# max     300.000000   350.000000

# %%
wer_df2.describe()
# Out:
#         WER for DS   WER for LA
# count  1457.000000  1457.000000
# mean     33.260207    25.250220
# std      31.752931    33.140923
# min       0.000000     0.000000
# 25%      13.043478     4.444444
# 50%      26.086957    15.555556
# 75%      46.296296    34.090909
# max     450.000000   450.000000

# %%
31.026844 - 29.045137
# Out:
# 1.981707

# %%
33.260207 - 25.250220
# Out:
# 8.009987000000002

# %%
# Plotting the graph for v1
sns.distplot(wer_df1["WER for DS"], label="WER for DS")
sns.distplot(wer_df1["WER for LA"], label="WER for LA")
plt.legend()
plt.show()

# %%
sns.distplot(wer_df2["WER for DS"], label="WER for DS")
sns.distplot(wer_df2["WER for LA"], label="WER for LA")
plt.legend()
plt.show()

# %% [markdown]
# ### According to wer module
# **For video 1, WER for LA is better by 1.98% <br />
#   For video 2, WER for LA is better by 8%**

# %% [markdown]
# ## Combining the entire output of DS/LA model to single file

# %%
# with open("reference_v1.txt", "w") as f:
#     for val in vdf1.iterrows():
#         f.write(val[1]["Reference"] + " ")
        
# with open("reference_v2.txt", "w") as f:
#     for val in vdf2.iterrows():
#         f.write(val[1]["Reference"] + " ")

# %%
# with open("ds_hyp_v1.txt", "w") as f1, open("la_hyp_v1.txt", "w") as f2:
#     for val in vdf1.iterrows():
#         f1.write(val[1]["Deepspeech hypothesis"] + " ")
#         f2.write(val[1]["Livai hypothesis"] + " ")
        
# with open("ds_hyp_v2.txt", "w") as f1, open("la_hyp_v2.txt", "w") as f2:
#     for val in vdf2.iterrows():
#         f1.write(val[1]["Deepspeech hypothesis"] + " ")
#         f2.write(val[1]["Livai hypothesis"] + " ")

# %% [markdown]
# ### wer.py is not able to calculate for huge text files

# %%
# print("Video 1, DS WER: ", wer.wer("reference_v1.txt", "ds_hyp_v1.txt"))
# print("Video 1, LA WER: ", wer.wer("reference_v1.txt", "la_hyp_v1.txt"))

# %%
# print("Video 2, DS WER: ", wer.wer("reference_v2.txt", "ds_hyp_v2.txt"))
# print("Video 2, LA WER: ", wer.wer("reference_v2.txt", "la_hyp_v2.txt"))

# %% [markdown]
# Cannot run WER on entire files, as they are very huge, RAM runs out of memory

# %% [markdown]
# # Calculating the WER using python wer module

# %%
# %%sh
# wer reference_v1.txt ds_hyp_v1.txt

# %% [markdown]
# Cannot run WER on entire files, as they are very huge, RAM runs out of memory

# %% [markdown]
# # Insights
#
# ### Using Deepspeech repo's WER module
# For video 1, WER for LA is better by **5.34%** than DS
# For video 2, WER for LA is better by **16.55%** than DS
#
# WER average for video 1: <br />
# WER for DS  =  47.2616<br />
# WER for LA  =  41.9199
#
# WER average for video 2: <br />
# WER for DS  =  53.3501<br />
# WER for LA  =  36.7991
#
# ### Using wer.py from a github repo
# For video 1, WER for LA is better by **1.98%** than DS
# For video 2, WER for LA is better by **8%** than DS
#
# WER average for video 1: <br />
# WER for DS  =  31.026844<br />
# WER for LA  =  29.045137
#
# WER average for video 2: <br />
# WER for DS  =  33.260207<br />
# WER for LA  =  25.250220

# %% [markdown]
# # Treat the outliers here

# %%
werds_df1.boxplot()

# %%
werds_df2.boxplot()

# %%
wer_df1.boxplot()
plt.show()

# %%
wer_df2.boxplot()

# %% [markdown]
# There are plenty of values that have WER above 1 or 100%.
# WER 0 means no error at all and 1 means its total error

# %%
vdf1
# Out:
#                                               Reference  \
# 0                the most beautiful thing about time is
# 1                      if you do something it passes by
# 2                        if you do nothing it passes by
# 3                        if you are joyful it passes by
# 4                     if you are miserable it passes by
# 5             its absolutely just no matter who you are
# 6                                           how you are
# 7              for everyboy it passes at the same speed
# 8     only thing is our experience of the time could...
# 9                  depending upon how intensely we live
# 10                                  or how slack we are
# 11                        if youre very slack with life
# 12         it looks like time is passing by very slowly
# 13                                if youre very intense
# 14                                   time just flies by
# 15    but in reality time is happening to all of us ...
# 16                                 these cycles of time
# 17    whether its minutes or hours or days or months...
# 18                                 these cycles of time
# 19      anything thats cyclical is naturally repetitive
# 20                        but anything that is cyclical
# 21         also has a centrifuge or a centrifugal force
# 22    a force which is always trying to go away at a...
# 23           if you ride this centrifugal force of time
# 24                               we say youre spiritual
# 25            if you are caught up in the cycle of time
# 26                            then thats being material
# 27               if youre crushed by the cycles of time
# 28             then we say you are a suffering creature
# 29                                 it is the same cycle
# ...                                                 ...
# 1544                           to wellbeing of children
# 1545                          who may not be theirs but
# 1546           when you have children who are not yours
# 1547  you have to do much more than what you would d...
# 1548  i need people like that who are willing to do ...
# 1549                  than they would do with their own
# 1550                           if there are such people
# 1551                a school will come together anyway
# 1552  if you live by this silly standard of what is ...
# 1553  anyway you will live in a very small space on ...
# 1554                                 and in this cosmos
# 1555  if you have no sense of what is yours and what...
# 1556                     everything will be open to you
# 1557                          thats my blessing to you
# 1558                     let the entire cosmos be yours
# 1559                                 why are you stingy
# 1560         why are you even stingy in your greediness
# 1561                at least in your greed be boundless
# 1562                                                hmm
# 1563                           im not saying generosity
# 1564                                    im saying greed
# 1565                             at least in your greed
# 1566                              let there be no limit
# 1567              that you want everything to be yours
# 1568                                        thats greed
# 1569                                           ultimate
# 1570                                 thats my blessing
# 1571          may you become greedy in a limitless way
# 1572  why are you stingy even on your greed eh\nstupid
# 1573                                             please
#
#                                   Deepspeech hypothesis  \
# 0                    most beautiful thing about time is
# 1                   i should do something it passes by
# 2                  they should do nothing it passes by
# 3                             i so joyful it passes by
# 4                         i so miserable it passes why
# 5              its absolutely get no matter who you are
# 6                                                o you
# 7                 everybody it passes of the same speed
# 8     one thing is our experience of the time could ...
# 9                   depenicuponor how intensely relive
# 10                                       or a slagkryar
# 11                           you ready slack would lie
# 12       it looked line time is passing my made slowly
# 13                                 if you were in tents
# 14                                   im just flash why
# 15    reality time is happening to all of us if the ...
# 16                                   the sales of time
# 17    he then its minutes or hours our days in month...
# 18                                   the sales of time
# 19      anything that pycookol is naturally levidtotiv
# 20                            anything that dicictacal
# 21             so it has a sentihuge or ascentituvefore
# 22    a force which is always sing to go away and at...
# 23         if you rivedngtdissentrthieen force of time
# 24                                    we say your bite
# 25                   if your cat at in the sale of time
# 26                            then thats being material
# 27                if you crushed by the cargoes of time
# 28                 then may say or a suffering creature
# 29                                it is the same psycho
# ...                                                 ...
# 1544                                 being of children
# 1545                                         obedeesbut
# 1546           then you have children who are not your
# 1547  you have to do much more than what you would d...
# 1548  people like that who are willing to do a lot m...
# 1549                 then they would go with their own
# 1550                            that are such people as
# 1551                          come to the other anyway
# 1552  if you live by this silistanderd of what is yo...
# 1553  anyway you we live in a very small space on th...
# 1554                               and in this crossmus
# 1555  if you have no sense of what is yours and what...
# 1556                            thing with the open to
# 1557                              thats my blessing to
# 1558                        than that cause must be or
# 1559                                      you you tiny
# 1560            why are you heinstiniyinyourbraaevinee
# 1561                                 or green bebanless
# 1562                                                 oh
# 1563                               i am not tingonaras
# 1564                                       amseinggreed
# 1565                            at least in your grief
# 1566                              let there be no limit
# 1567                  that you want everything to be a
# 1568                                         that gleam
# 1569                                          ultimate
# 1570                                   that my blessing
# 1571               may become greedy in a limitless way
# 1572         why was tiny you want on your green to it
# 1573                                              fish
#
#                                        Livai hypothesis
# 0                    most beautiful thing about time is
# 1                      if you do something it passes by
# 2                      if you do nothing yet passage by
# 3                          if you join for it places by
# 4                              is major ko ek prices by
# 5             its absolutely just no matter who you are
# 6                                              kahan ho
# 7                    everybody it passes the same speed
# 8     only thing is our experience of the time could...
# 9                         defening upon how intensively
# 10                                 or house slack where
# 11                       is your very slacks with light
# 12                   it looks like time spacing bar bar
# 13                                          if you were
# 14                                    i m just flies by
# 15    i then reality time is happening all of as in ...
# 16                               these cycles sacha hai
# 17    whether its minutes or hours or days months or...
# 18                                  this cycles of time
# 19    anything that's my cracker is naturally vegita...
# 20                                     anything that is
# 21       so has a centrifuge or a center you will force
# 22    of course which is always trying to go away at...
# 23            if you write this center fuel forces time
# 24                           we see your stories holmes
# 25            if you are caught up in the cycle of time
# 26                                    then that's being
# 27             if you are crushed by the cycles of time
# 28                        then mess high your suffering
# 29                                       it is the same
# ...                                                 ...
# 1544                   twelve being up chal raha hai ho
# 1545                           main ne abhi there's but
# 1546            when you have children hu are not yours
# 1547  you have to do much more than what you would d...
# 1548  many people like that who are willing to do a ...
# 1549                  then they would do with their own
# 1550                              there are such people
# 1551                    who will come together in a buy
# 1552  if you leave by this still standard of what is...
# 1553  anywhere you live in a very small space on thi...
# 1554                                   and in this cost
# 1555  if you have no sense of what is yours and what...
# 1556                      the thing will be opened here
# 1557                      that's my blessing to you the
# 1558                      the entire cost must be yours
# 1559                             what i are you stain j
# 1560  why are you even still g in your grade nine eight
# 1561                              its in your green bee
# 1562                                               haan
# 1563                                    i am not saying
# 1564                                  i am saying great
# 1565                             at least in your greed
# 1566                              let there be no limit
# 1567               that you want everything to be yours
# 1568                                       that's green
# 1569                                           ultimate
# 1570                                    that's my place
# 1571          me you become greedy in a limitless where
# 1572          why are you staying even on your greed to
# 1573
#
# [1574 rows x 3 columns]
